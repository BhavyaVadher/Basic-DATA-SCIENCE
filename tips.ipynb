# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"D:\AI_ML\NOTEBOOK\tips.csv")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
sns.set_style("darkgrid")
sns.barplot(x="sex",y="total_bill",data=df)
# Out:
# <AxesSubplot: xlabel='sex', ylabel='total_bill'>

# %%
sns.set_style("darkgrid")
sns.barplot(x="sex",y="total_bill",data=df,palette="plasma")
# Out:
# <AxesSubplot: xlabel='sex', ylabel='total_bill'>

# %%
sns.boxplot(x="day",y="total_bill",data=df,palette="plasma")
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="sex",y="total_bill",data=df,palette="plasma")
# Out:
# <AxesSubplot: xlabel='sex', ylabel='total_bill'>

# %%
sns.stripplot(x="sex",y="total_bill",data=df,palette="plasma")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7768\899738704.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(x="sex",y="total_bill",data=df,palette="plasma")
# <AxesSubplot: xlabel='sex', ylabel='total_bill'>

# %%
sns.swarmplot(x="sex",y="total_bill",data=df,palette="plasma")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7768\804426376.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(x="sex",y="total_bill",data=df,palette="plasma")
# <AxesSubplot: xlabel='sex', ylabel='total_bill'>

# %%
sns.swarmplot(x="sex",y="total_bill",data=df,palette="plasma")
sns.violinplot(x="sex",y="total_bill",data=df,color="blue")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7768\1857116917.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(x="sex",y="total_bill",data=df,palette="plasma")
# <AxesSubplot: xlabel='sex', ylabel='total_bill'>

# %%
sns.factorplot(x="sex",y="total_bill",data=df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [41], line 1
# ----> 1 sns.factorplot(x="sex",y="total_bill",data=df)
#
# AttributeError: module 'seaborn' has no attribute 'factorplot'

# %%
pip install -U seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
